# %%
from IPython import display

# %% [markdown]
# ### In this nootbook I have train a pretrain segment model on our custom dataset.

# %% [markdown]
# #### I've done extra prepossing on the data from Roboflow.

# %%
# load the data from Roboflow 

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="****************")
project = rf.workspace("cattle-weight").project("segma")
dataset = project.version(3).download("yolov8")

display.clear_output()

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5432.2/8062.4 GB disk)

# %%
# !cd /kaggle/working/

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')
model.to('cuda')

display.clear_output()

# %%
results = model.train(data='/kaggle/input/nsjfkkk/data (2).yaml', epochs=12, imgsz=640, device=[0, 1])
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
#                                                      CUDA:1 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Loding the newly trained model.

# %%
model = YOLO('/kaggle/working/runs/segment/train2/weights/best.pt')

# %%
model.predict('/kaggle/input/nsshda/cow-Holstein-Friesian.webp', save=True, conf=0.5)
# Out:
# image 1/1 /kaggle/input/nsshda/cow-Holstein-Friesian.webp: 416x640 1 0, 13.0ms
# Speed: 2.3ms preprocess, 13.0ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/segment/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: '0', 1: '1'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
# ...
