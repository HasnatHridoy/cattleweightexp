# %%
# I have done extra preprocessing on the data from Roboflow. 
# So I need to pull the data from there

# !pip install roboflow
from IPython import display

from roboflow import Roboflow
rf = Roboflow(api_key="********************")
project = rf.workspace("cattle-weight").project("cow_body")
dataset = project.version(2).download("yolov8")
display.clear_output()

# %% [markdown]
# ### In this notebook we train a pretrain Object dectection model on our custom dataset.

# %%
# !pip install ultralytics
display.clear_output()

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 151MB/s]

# %%
# !cd /kaggle/working/

# %%
model.to('cuda')
display.clear_output()

# %%
results = model.train(data='/kaggle/input/yamlss/data (5).yaml', epochs = 30, imgsz=640, batch=16, patience=20)
# Out:
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/kaggle/input/yamlss/data (5).yaml, epochs=30, time=None, patience=20, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cuda:0, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=Fals
# ...

# %%
model = YOLO('/kaggle/working/runs/detect/train2/weights/last.pt')

# %%
result = model.predict('/kaggle/input/kkkkkj/black-white-cow-4177366.webp', save = True)
# Out:
# image 1/1 /kaggle/input/kkkkkj/black-white-cow-4177366.webp: 448x640 1 cattle-biometrics NEW, 73.2ms
# Speed: 2.1ms preprocess, 73.2ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
